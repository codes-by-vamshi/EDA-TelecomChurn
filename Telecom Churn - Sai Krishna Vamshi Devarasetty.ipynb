# %% [markdown]
# # Exploratory Data Analysis - Telecom Churn (Capstone Project 1)

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# #### 1. Reading Data from CSV file to Pandas DataFrame

# %%
TelecomChurnDF = pd.read_csv('./Telecom-Churn.csv')
TelecomChurnDF
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 2. Finding if any missing values in any column

# %%
def FindNullValues(df):
    print(df.isnull().sum())

FindNullValues(TelecomChurnDF)
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# ###### Woo Hoo !! No missing Values

# %% [markdown]
# #### 3. Finding Data types of Columns

# %%
TelecomChurnDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %% [markdown]
# ##### Excpet the columns State, International plan, Voice mail plan and Churn remaining all are Numerical (either int or float)

# %% [markdown]
# #### 4. Statistical Description of Data (For Numerical Columns)

# %%
TelecomChurnDF.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# std          20.069084          9.259435          50.713844        19.922625
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.430000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.790000         235.300000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       3333.000000          3333.000000        3333.000000
# mean          17.083540           200.872037         100.107711
# std            4.310668            50.573847          19.568609
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls
# count        3333.000000             3333.000000
# mean            2.764581                1.562856
# std             0.753773                1.315491
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.780000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %% [markdown]
# #### 5. Dividing DataFrame into two parts(Churn = True and Churn = False), so we can compare the user behavior who churned with non churned

# %%
ChurnedDF = TelecomChurnDF[TelecomChurnDF['Churn'] == True]
ChurnedDF
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 10                        0              129.1              137
# 15                        0              332.9               67
# 21                        0               62.4               89
# 33                        0              249.6              118
# 41                       41              173.1               85
# ...                     ...                ...              ...
# 3301                      0              280.0              113
# 3304                      0              186.1              114
# 3320                      0              140.0              101
# 3322                      0              321.1              105
# 3323                      0              118.4              126
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 10               21.95              228.5               83             19.42
# 15               56.59              317.8               97             27.01
# 21               10.61              169.9              121             14.44
# 33               42.43              252.4              119             21.45
# 41               29.43              203.9              107             17.33
# ...                ...                ...              ...               ...
# 3301             47.60              202.2               90             17.19
# 3304             31.64              198.6              140             16.88
# 3320             23.80              196.4               77             16.69
# 3322             54.59              265.5              122             22.57
# 3323             20.13              249.3               97             21.19
#
#       Total night minutes  Total night calls  Total night charge  \
# 10                  208.8                111                9.40
# 15                  160.6                128                7.23
# 21                  209.6                 64                9.43
# 33                  280.2                 90               12.61
# 41                  122.2                 78                5.50
# ...                   ...                ...                 ...
# 3301                156.8                103                7.06
# 3304                206.5                 80                9.29
# 3320                120.1                133                5.40
# 3322                180.5                 72                8.12
# 3323                227.0                 56               10.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 10                  12.7                 6               3.43
# 15                   5.4                 9               1.46
# 21                   5.7                 6               1.54
# 33                  11.8                 3               3.19
# 41                  14.6                15               3.94
# ...                  ...               ...                ...
# 3301                10.4                 4               2.81
# 3304                13.8                 5               3.73
# 3320                 9.7                 4               2.62
# 3322                11.5                 2               3.11
# 3323                13.6                 3               3.67
#
#       Customer service calls  Churn
# 10                         4   True
# 15                         4   True
# 21                         5   True
# 33                         1   True
# 41                         0   True
# ...                      ...    ...
# 3301                       0   True
# 3304                       4   True
# 3320                       4   True
# 3322                       4   True
# 3323                       5   True
#
# [483 rows x 20 columns]

# %%
NonChurnedDF = TelecomChurnDF[TelecomChurnDF['Churn'] == False]
NonChurnedDF
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [2850 rows x 20 columns]

# %% [markdown]
# #### Out of Total 3333 users in data set 483 have churned and 2850 didn't

# %% [markdown]
# #### 6. Frequency Comparison of Day, Evening and Night minutes in Both DataFrames

# %%
fig, axs = plt.subplots(3,2, figsize=(20,20))
axs[0, 0].hist(ChurnedDF['Total day minutes'])
axs[0, 0].set_title('Churned Day Minutes')
axs[0, 1].hist(NonChurnedDF['Total day minutes'])
axs[0, 1].set_title('Non Churned Day Minutes')
axs[1, 0].hist(ChurnedDF['Total eve minutes'])
axs[1, 0].set_title('Churned Evening Minutes')
axs[1, 1].hist(NonChurnedDF['Total eve minutes'])
axs[1, 1].set_title('Non Churned Evening Minutes')
axs[2, 0].hist(ChurnedDF['Total night minutes'])
axs[2, 0].set_title('Churned Night Minutes')
axs[2, 1].hist(NonChurnedDF['Total night minutes'])
axs[2, 1].set_title('Non Churned Night Minutes')

for ax in axs.flat:
    ax.set(xlabel='No. of Minutes', ylabel='No. of Users')

# %% [markdown]
# #### 7. Frequency Comparison of Day, Evening and Night Calls in Both DataFrames

# %%
fig, axs = plt.subplots(3,2, figsize=(20,20))
axs[0, 0].hist(ChurnedDF['Total day calls'])
axs[0, 0].set_title('Churned Day Calls')
axs[0, 1].hist(NonChurnedDF['Total day calls'])
axs[0, 1].set_title('Non Churned Day Calls')
axs[1, 0].hist(ChurnedDF['Total eve calls'])
axs[1, 0].set_title('Churned Evening Calls')
axs[1, 1].hist(NonChurnedDF['Total eve calls'])
axs[1, 1].set_title('Non Churned Evening Calls')
axs[2, 0].hist(ChurnedDF['Total night calls'])
axs[2, 0].set_title('Churned Night Calls')
axs[2, 1].hist(NonChurnedDF['Total night calls'])
axs[2, 1].set_title('Non Churned Night Calls')

for ax in axs.flat:
    ax.set(xlabel='No. of Calls', ylabel='No. of Users')

# %% [markdown]
# #### 8. Frequency Comparison of Day, Evening and Night Charges in Both DataFrames

# %%
fig, axs = plt.subplots(3,2, figsize=(20,20))
axs[0, 0].hist(ChurnedDF['Total day charge'])
axs[0, 0].set_title('Churned Day Charge')
axs[0, 1].hist(NonChurnedDF['Total day charge'])
axs[0, 1].set_title('Non Churned Day Charge')
axs[1, 0].hist(ChurnedDF['Total eve charge'])
axs[1, 0].set_title('Churned Evening Charge')
axs[1, 1].hist(NonChurnedDF['Total eve charge'])
axs[1, 1].set_title('Non Churned Evening Charge')
axs[2, 0].hist(ChurnedDF['Total night charge'])
axs[2, 0].set_title('Churned Night Charge')
axs[2, 1].hist(NonChurnedDF['Total night charge'])
axs[2, 1].set_title('Non Churned Night Charge')

for ax in axs.flat:
    ax.set(xlabel='Total Charge', ylabel='No. of Users')

# %% [markdown]
# #### 9. Finding Correlation among Morning,Evening and Night call minutes attributes and plotting Heat Map

# %%
TelecomChurnCallMinutesDF = TelecomChurnDF[['Total day minutes','Total eve minutes','Total night minutes']]
TelecomChurnCallMinutesCorrData = TelecomChurnCallMinutesDF.corr()
sns.heatmap(TelecomChurnCallMinutesCorrData, vmin=-1, vmax=1)
TelecomChurnCallMinutesCorrData
# Out:
#                      Total day minutes  Total eve minutes  Total night minutes
# Total day minutes             1.000000           0.007043             0.004323
# Total eve minutes             0.007043           1.000000            -0.012584
# Total night minutes           0.004323          -0.012584             1.000000

# %% [markdown]
# #### 10. Finding Correlation among Morning,Evening and Night calls attributes and plotting Heat Map

# %%
TelecomChurnCallsDF = TelecomChurnDF[['Total day calls','Total eve calls','Total night calls']]
TelecomChurnCallsCorrData = TelecomChurnCallsDF.corr()
sns.heatmap(TelecomChurnCallsCorrData, vmin=-1, vmax=1)
TelecomChurnCallsCorrData
# Out:
#                    Total day calls  Total eve calls  Total night calls
# Total day calls           1.000000         0.006462          -0.019557
# Total eve calls           0.006462         1.000000           0.007710
# Total night calls        -0.019557         0.007710           1.000000

# %% [markdown]
# #### 11. Finding Correlation among Morning,Evening and Night call charges attributes and plotting Heat Map

# %%
TelecomChurnCallChargesDF = TelecomChurnDF[['Total day charge','Total eve charge','Total night charge']]
TelecomChurnCallChargesCorrData = TelecomChurnCallChargesDF.corr()
sns.heatmap(TelecomChurnCallChargesCorrData, vmin=-1, vmax=1)
TelecomChurnCallChargesCorrData
# Out:
#                     Total day charge  Total eve charge  Total night charge
# Total day charge            1.000000          0.007036            0.004301
# Total eve charge            0.007036          1.000000           -0.012601
# Total night charge          0.004301         -0.012601            1.000000

# %% [markdown]
# #### Important insight from above 3 Correlation Data is that duration of the time either day, evening or night has almost 0 correlation among themselves

# %% [markdown]
# #### 11. Seggregating Data based on Area Code for Analysis

# %%
uniqueAreaCodes = list(TelecomChurnDF['Area code'].unique())
print("Area Codes in Data are ", uniqueAreaCodes)
# Out:
# Area Codes in Data are  [415, 408, 510]

# %%
DictOfTelecomChurnDFBasedOnAreaCodes = {}
for i in uniqueAreaCodes:
    DictOfTelecomChurnDFBasedOnAreaCodes[i] = TelecomChurnDF[TelecomChurnDF['Area code'] == i]

# %% [markdown]
# #### So we have 3 area codes 415,408 and 510

# %%
print('-------------- Area Code',415,'--------------')
DictOfTelecomChurnDFBasedOnAreaCodes[415]
# Out:
# -------------- Area Code 415 --------------
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 4       OK              75        415                Yes              No
# 7       MO             147        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 4                         0              166.7              113
# 7                         0              157.0               79
# ...                     ...                ...              ...
# 3326                      0              106.6              128
# 3327                      0              134.7               98
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 4                28.34              148.3              122             12.61
# 7                26.69              103.1               94              8.76
# ...                ...                ...              ...               ...
# 3326             18.12              284.8               87             24.21
# 3327             22.90              189.7               68             16.12
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 4                   186.9                121                8.41
# 7                   211.8                 96                9.53
# ...                   ...                ...                 ...
# 3326                178.9                 92                8.05
# 3327                221.4                128                9.96
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 4                   10.1                 3               2.73
# 7                    7.1                 6               1.92
# ...                  ...               ...                ...
# 3326                14.9                 7               4.02
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 4                          3  False
# 7                          0  False
# ...                      ...    ...
# 3326                       1  False
# 3327                       2  False
# 3328                       2  False
# 3329                       3  False
# 3332                       0  False
#
# [1655 rows x 20 columns]

# %%
print('-------------- Area Code',408,'--------------')
DictOfTelecomChurnDFBasedOnAreaCodes[408]
# Out:
# -------------- Area Code 408 --------------
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 8       LA             117        408                 No              No
# 12      IA             168        408                 No              No
# 16      ID              85        408                 No             Yes
# 21      CO              77        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3309    VT             100        408                Yes              No
# 3312    SC             181        408                 No              No
# 3313    ID             127        408                 No              No
# 3322    MD              62        408                 No              No
# 3325    OH              78        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3                         0              299.4               71
# 8                         0              184.5               97
# 12                        0              128.8               96
# 16                       27              196.4              139
# 21                        0               62.4               89
# ...                     ...                ...              ...
# 3309                      0              219.4              112
# 3312                      0              229.9              130
# 3313                      0              102.8              128
# 3322                      0              321.1              105
# 3325                      0              193.4               99
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3                50.90               61.9               88              5.26
# 8                31.37              351.6               80             29.89
# 12               21.90              104.9               71              8.92
# 16               33.39              280.9               90             23.88
# 21               10.61              169.9              121             14.44
# ...                ...                ...              ...               ...
# 3309             37.30              225.7              102             19.18
# 3312             39.08              144.4               93             12.27
# 3313             17.48              143.7               95             12.21
# 3322             54.59              265.5              122             22.57
# 3325             32.88              116.9               88              9.94
#
#       Total night minutes  Total night calls  Total night charge  \
# 3                   196.9                 89                8.86
# 8                   215.8                 90                9.71
# 12                  141.1                128                6.35
# 16                   89.3                 75                4.02
# 21                  209.6                 64                9.43
# ...                   ...                ...                 ...
# 3309                255.3                 95               11.49
# 3312                262.4                110               11.81
# 3313                191.4                 97                8.61
# 3322                180.5                 72                8.12
# 3325                243.3                109               10.95
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3                    6.6                 7               1.78
# 8                    8.7                 4               2.35
# 12                  11.2                 2               3.02
# 16                  13.8                 4               3.73
# 21                   5.7                 6               1.54
# ...                  ...               ...                ...
# 3309                12.0                 4               3.24
# 3312                14.2                 4               3.83
# 3313                10.0                 5               2.70
# 3322                11.5                 2               3.11
# 3325                 9.3                 4               2.51
#
#       Customer service calls  Churn
# 3                          2  False
# 8                          1  False
# 12                         1  False
# 16                         1  False
# 21                         5   True
# ...                      ...    ...
# 3309                       4  False
# 3312                       2  False
# 3313                       1  False
# 3322                       4   True
# 3325                       2  False
#
# [838 rows x 20 columns]

# %%
print('-------------- Area Code',510,'--------------')
DictOfTelecomChurnDFBasedOnAreaCodes[510]
# Out:
# -------------- Area Code 510 --------------
#      State  Account length  Area code International plan Voice mail plan  \
# 5       AL             118        510                Yes              No
# 6       MA             121        510                 No             Yes
# 13      MT              95        510                 No              No
# 17      VT              93        510                 No              No
# 18      VA              76        510                 No             Yes
# ...    ...             ...        ...                ...             ...
# 3304    IL              71        510                Yes              No
# 3316    MS             103        510                 No             Yes
# 3320    GA             122        510                Yes              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 5                         0              223.4               98
# 6                        24              218.2               88
# 13                        0              156.6               88
# 17                        0              190.7              114
# 18                       33              189.7               66
# ...                     ...                ...              ...
# 3304                      0              186.1              114
# 3316                     29              164.1              111
# 3320                      0              140.0              101
# 3330                      0              180.8              109
# 3331                      0              213.8              105
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 5                37.98              220.6              101             18.75
# 6                37.09              348.5              108             29.62
# 13               26.62              247.6               75             21.05
# 17               32.42              218.2              111             18.55
# 18               32.25              212.8               65             18.09
# ...                ...                ...              ...               ...
# 3304             31.64              198.6              140             16.88
# 3316             27.90              219.1               96             18.62
# 3320             23.80              196.4               77             16.69
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
#
#       Total night minutes  Total night calls  Total night charge  \
# 5                   203.9                118                9.18
# 6                   212.6                118                9.57
# 13                  192.3                115                8.65
# 17                  129.6                121                5.83
# 18                  165.7                108                7.46
# ...                   ...                ...                 ...
# 3304                206.5                 80                9.29
# 3316                220.3                108                9.91
# 3320                120.1                133                5.40
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 5                    6.3                 6               1.70
# 6                    7.5                 7               2.03
# 13                  12.3                 5               3.32
# 17                   8.1                 3               2.19
# 18                  10.0                 5               2.70
# ...                  ...               ...                ...
# 3304                13.8                 5               3.73
# 3316                12.3                 9               3.32
# 3320                 9.7                 4               2.62
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
#
#       Customer service calls  Churn
# 5                          0  False
# 6                          3  False
# 13                         3  False
# 17                         3  False
# 18                         1  False
# ...                      ...    ...
# 3304                       4   True
# 3316                       0  False
# 3320                       4   True
# 3330                       2  False
# 3331                       2  False
#
# [840 rows x 20 columns]

# %% [markdown]
# #### Comaprison and Analysis of Churn Vs Non Churn Area Code wise

# %%
AreaCodeWiseChurnAndNonChurn = {}
AreaCodeWiseChurnAndNonChurn['Churn'] = {} # Nested Dictionary 
AreaCodeWiseChurnAndNonChurn['NonChurn'] = {} # Nested Dictionary
for i in uniqueAreaCodes:
    areaCodeData = DictOfTelecomChurnDFBasedOnAreaCodes[i]
    # Adding Churn Data to Churn Key (nested Dict)
    AreaCodeWiseChurnAndNonChurn['Churn'][i] = areaCodeData[areaCodeData['Churn'] == True]
    # Adding Non Churn Data to NonChurn Key (nested Dict)
    AreaCodeWiseChurnAndNonChurn['NonChurn'][i] = areaCodeData[areaCodeData['Churn'] == False]

# %% [markdown]
# #### Explaining The Nested Dictionary Format that we formed Above
# AreaCodeWiseChurnAndNonChurn = {
# >     'Churn': {
#              415: DataFrame of 415 Area Code with Churn equal to True,
#              408: DataFrame of 408 Area Code with Churn equal to True,
#              510: DataFrame of 510 Area Code with Churn equal to True
#         },
#         'NonChurn': {
#             415: DataFrame of 415 Area Code with Churn equal to False,
#             408: DataFrame of 408 Area Code with Churn equal to False,
#             510: DataFrame of 510 Area Code with Churn equal to False
#         }
#    }

# %% [markdown]
# #### 12. Data Comparison of Day, Evening and Night minutes of Both Churn and Non Churn with in Area Codes

# %% [markdown]
# > ##### 12.1 Area Code - 415

# %%
print('Area Code 415 Churned Users Call Minutes')
AreaCodeWiseChurnAndNonChurn['Churn'][415].boxplot(['Total day minutes', 'Total eve minutes', 'Total night minutes'])
# Out:
# Area Code 415 Churned Users Call Minutes
# <AxesSubplot:>

# %%
print('Area Code 415 Non Churned Users Call Minutes')
AreaCodeWiseChurnAndNonChurn['NonChurn'][415].boxplot(['Total day minutes', 'Total eve minutes', 'Total night minutes'])
# Out:
# Area Code 415 Non Churned Users Call Minutes
# <AxesSubplot:>

# %% [markdown]
# > ##### 12.2 Area Code - 408

# %%
print('Area Code 408 Churned Users Call Minutes')
AreaCodeWiseChurnAndNonChurn['Churn'][408].boxplot(['Total day minutes', 'Total eve minutes', 'Total night minutes'])
# Out:
# Area Code 408 Churned Users Call Minutes
# <AxesSubplot:>

# %%
print('Area Code 408 Non Churned Users Call Minutes')
AreaCodeWiseChurnAndNonChurn['NonChurn'][408].boxplot(['Total day minutes', 'Total eve minutes', 'Total night minutes'])
# Out:
# Area Code 408 Non Churned Users Call Minutes
# <AxesSubplot:>

# %% [markdown]
# > ##### 12.3 Area Code - 510

# %%
print('Area Code 510 Churned Users Call Minutes')
AreaCodeWiseChurnAndNonChurn['Churn'][510].boxplot(['Total day minutes', 'Total eve minutes', 'Total night minutes'])
# Out:
# Area Code 510 Churned Users Call Minutes
# <AxesSubplot:>

# %%
print('Area Code 510 Non Churned Users Call Minutes')
AreaCodeWiseChurnAndNonChurn['NonChurn'][510].boxplot(['Total day minutes', 'Total eve minutes', 'Total night minutes'])
# Out:
# Area Code 510 Non Churned Users Call Minutes
# <AxesSubplot:>

# %% [markdown]
# #### In all 3 Area Codes, the median of day and evening minutes is more in Churned users compared to Non Churned users, and for night it's comparable(Churned is slightly high)
#
# #### And also if we see the IQR(Inter Quartile Range) is spread more for Churned Users

# %% [markdown]
# #### 13. State Based Churn and Non Churned User Data Analysis

# %% [markdown]
# > #### 13.1 Counting Number of Users Churned and Non Churned State wise

# %%
uniqueStates = list(TelecomChurnDF['State'].unique())
print("Unique States in Data are ", uniqueStates)
print('---------------------------------')
StateWiseChurnedAndNonChurnedCounts = TelecomChurnDF.groupby(['State', 'Churn'])['Churn'].count()
print("State wise Churn and Non Churn Count")
StateWiseChurnedAndNonChurnedCounts
# Out:
# Unique States in Data are  ['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI', 'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC', 'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR', 'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC', 'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND']
# ---------------------------------
# State wise Churn and Non Churn Count
# State  Churn
# AK     False    49
#        True      3
# AL     False    72
#        True      8
# AR     False    44
#                 ..
# WI     True      7
# WV     False    96
#        True     10
# WY     False    68
#        True      9
# Name: Churn, Length: 102, dtype: int64

# %% [markdown]
# > #### 13.2 Finding out states with high Churn rate (> 20%)

# %%
StateChurnedPercentage = {}
for i in uniqueStates:
    StateChurnedPercentage[i] = (StateWiseChurnedAndNonChurnedCounts.loc[i,True])/(StateWiseChurnedAndNonChurnedCounts.loc[i,True] + StateWiseChurnedAndNonChurnedCounts.loc[i,False])
print('State wise Churn Rate')
print(StateChurnedPercentage)
print('----------------------')
print('States with more than 20% churn rate')
StateChurnedPercentageMoreThan20 = {k:v for k,v in StateChurnedPercentage.items() if v>0.2}
print(StateChurnedPercentageMoreThan20)
# Out:
# State wise Churn Rate
# {'KS': 0.18571428571428572, 'OH': 0.1282051282051282, 'NJ': 0.2647058823529412, 'OK': 0.14754098360655737, 'AL': 0.1, 'MA': 0.16923076923076924, 'MO': 0.1111111111111111, 'LA': 0.0784313725490196, 'WV': 0.09433962264150944, 'IN': 0.1267605633802817, 'RI': 0.09230769230769231, 'IA': 0.06818181818181818, 'MT': 0.20588235294117646, 'NY': 0.18072289156626506, 'ID': 0.1232876712328767, 'VT': 0.1095890410958904, 'VA': 0.06493506493506493, 'TX': 0.25, 'FL': 0.12698412698412698, 'CO': 0.13636363636363635, 'AZ': 0.0625, 'SC': 0.23333333333333334, 'NE': 0.08196721311475409, 'WY': 0.11688311688311688, 'HI': 0.05660377358490566, 'IL': 0.08620689655172414, 'NH': 0.16071428571428573, 'GA': 0.14814814814814814, 'AK': 0.057692307692307696, 'MD': 0.24285714285714285, 'AR': 0.2, 'WI': 0.08974358974358974, 'OR': 0.14102564102564102, 'MI': 0.2191780821917808, 'DE': 0.14754098360655737, 'UT': 0.1388888888888889, 'CA': 0.2647058823529412, 'MN': 0.17857142857142858, 'SD': 0.13333333333333333, 'NC': 0.16176470588235295, 'WA': 0.21212121212121213, 'NM': 0.0967741935483871, 'NV': 0.21212121212121213, 'DC': 0.09259259259259259, 'KY': 0.13559322033898305, 'ME': 0.20967741935483872, 'MS': 0.2153846153846154, 'TN': 0.09433962264150944, 'PA': 0.17777777777777778, 'CT': 0.16216216216216217, 'ND': 0.0967741935483871}
# ----------------------
# States with more than 20% churn rate
# {'NJ': 0.2647058823529412, 'MT': 0.20588235294117646, 'TX': 0.25, 'SC': 0.23333333333333334, 'MD': 0.24285714285714285, 'MI': 0.2191780821917808, 'CA': 0.2647058823529412, 'WA': 0.21212121212121213, 'NV': 0.21212121212121213, 'ME': 0.20967741935483872, 'MS': 0.2153846153846154}

# %%
plt.bar(*zip(*StateChurnedPercentageMoreThan20.items()))
plt.title('States with Churn Percentage > 20%')
plt.xlabel('State')
plt.ylabel('Churn Rate')
# Out:
# Text(0, 0.5, 'Churn Rate')

# %% [markdown]
# #### Out of 51 states 11 states have more than 20% Churned Users
#
# #### States NJ and CA have highest Churn rate of 26.47%

# %% [markdown]
# #### 14. International Plan Based Churn and Non Churned User Data Analysis

# %% [markdown]
# > #### 14.1 Counting Number of Users Churned and Non Churned Based on wheather opted International Plan or not

# %%
ChurnedAndNonChurnedCountsBasedOnInternationalPlan = TelecomChurnDF.groupby(['International plan', 'Churn'])['Churn'].count()
print("Churn and Non Churn Count Based on Opting for International Plan")
ChurnedAndNonChurnedCountsBasedOnInternationalPlan
# Out:
# Churn and Non Churn Count Based on Opting for International Plan
# International plan  Churn
# No                  False    2664
#                     True      346
# Yes                 False     186
#                     True      137
# Name: Churn, dtype: int64

# %% [markdown]
# > #### 14.2 Comparison plot between who opted International Plan and Not

# %%
ChurnedPercentBasedOnInternationalPlan = {}
ChurnedPercentBasedOnInternationalPlan['Yes'] = (ChurnedAndNonChurnedCountsBasedOnInternationalPlan.loc['Yes',True])/((ChurnedAndNonChurnedCountsBasedOnInternationalPlan.loc['Yes',True])+(ChurnedAndNonChurnedCountsBasedOnInternationalPlan.loc['Yes',False]))
ChurnedPercentBasedOnInternationalPlan['No'] = (ChurnedAndNonChurnedCountsBasedOnInternationalPlan.loc['No',True])/((ChurnedAndNonChurnedCountsBasedOnInternationalPlan.loc['Yes',True])+(ChurnedAndNonChurnedCountsBasedOnInternationalPlan.loc['No',False]))
plt.bar(*zip(*ChurnedPercentBasedOnInternationalPlan.items()))
plt.title('Churned rate Comparision based on Opting International Paln')
plt.xlabel('Opted International Plan')
plt.ylabel('Churn Rate')
# Out:
# Text(0, 0.5, 'Churn Rate')

# %% [markdown]
# #### We can clearly see users who opted for International Plan has churned almost 4 times(more than 40%) when compared to users who didn't opt

# %% [markdown]
# #### 15.Voice Mail Plan Based Churn and Non Churned User Data Analysis

# %% [markdown]
# > #### 15.1 Counting Number of Users Churned and Non Churned Based on wheather opted Voice mail plan or not

# %%
ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan = TelecomChurnDF.groupby(['Voice mail plan', 'Churn'])['Churn'].count()
print("Churn and Non Churn Count Based on Opting for Voice mail Plan")
ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan
# Out:
# Churn and Non Churn Count Based on Opting for Voice mail Plan
# Voice mail plan  Churn
# No               False    2008
#                  True      403
# Yes              False     842
#                  True       80
# Name: Churn, dtype: int64

# %% [markdown]
# > #### 15.2 Comparison plot between who opted Voice Plan and Not

# %%
ChurnedPercentBasedOnVoiceMailPlan = {}
ChurnedPercentBasedOnVoiceMailPlan['Yes'] = (ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan.loc['Yes',True])/((ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan.loc['Yes',True])+(ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan.loc['Yes',False]))
ChurnedPercentBasedOnVoiceMailPlan['No'] = (ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan.loc['No',True])/((ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan.loc['Yes',True])+(ChurnedAndNonChurnedCountsBasedOnVoiceMailPlan.loc['No',False]))
plt.bar(*zip(*ChurnedPercentBasedOnVoiceMailPlan.items()))
plt.title('Churned rate Comparision based on Opting Voice mail Paln')
plt.xlabel('Opted Voice mail Plan')
plt.ylabel('Churn Rate')
# Out:
# Text(0, 0.5, 'Churn Rate')

# %% [markdown]
# #### This gives conclusion that voice mail has not impacted in high churn rate but in a way users who opted for Voice mail plan are satisfied with the service

# %% [markdown]
# #### 16. Analysis based on Number of Customer Service Calls made

# %%
print('Percentage Distribution for number of Service Calls made')
print('---------------------------------------------')
print(TelecomChurnDF['Customer service calls'].value_counts(normalize=True).sort_index())
TelecomChurnDF['Customer service calls'].value_counts().sort_index().plot(kind='bar', xlabel='No. of Service Calls', ylabel='Frequency')
# Out:
# Percentage Distribution for number of Service Calls made
# ---------------------------------------------
# 0    0.209121
# 1    0.354335
# 2    0.227723
# 3    0.128713
# 4    0.049805
# 5    0.019802
# 6    0.006601
# 7    0.002700
# 8    0.000600
# 9    0.000600
# Name: Customer service calls, dtype: float64
# <AxesSubplot:xlabel='No. of Service Calls', ylabel='Frequency'>

# %%
print('Percentage Distribution of Churned Users for number of Service Calls made')
print('---------------------------------------------')
print(ChurnedDF['Customer service calls'].value_counts(normalize=True).sort_index())
ChurnedDF['Customer service calls'].value_counts().sort_index().plot(kind='bar', xlabel='No. of Service Calls', ylabel='Frequency')
# Out:
# Percentage Distribution of Churned Users for number of Service Calls made
# ---------------------------------------------
# 0    0.190476
# 1    0.252588
# 2    0.180124
# 3    0.091097
# 4    0.157350
# 5    0.082816
# 6    0.028986
# 7    0.010352
# 8    0.002070
# 9    0.004141
# Name: Customer service calls, dtype: float64
# <AxesSubplot:xlabel='No. of Service Calls', ylabel='Frequency'>

# %%
print('Percentage Distribution of Non Churned Users for number of Service Calls made')
print('---------------------------------------------')
print(NonChurnedDF['Customer service calls'].value_counts(normalize=True).sort_index())
NonChurnedDF['Customer service calls'].value_counts().sort_index().plot(kind='bar', xlabel='No. of Service Calls', ylabel='Frequency')
# Out:
# Percentage Distribution of Non Churned Users for number of Service Calls made
# ---------------------------------------------
# 0    0.212281
# 1    0.371579
# 2    0.235789
# 3    0.135088
# 4    0.031579
# 5    0.009123
# 6    0.002807
# 7    0.001404
# 8    0.000351
# Name: Customer service calls, dtype: float64
# <AxesSubplot:xlabel='No. of Service Calls', ylabel='Frequency'>

# %% [markdown]
# #### From the plot it is evident that those users who are making more than or equal to 4 serivice call are most likely to Churn
